# %%
from collections import defaultdict
import numpy as np

# %%
Q = defaultdict(lambda: np.zeros(4))

# %%
Q[0][:] = 0.25

# %%
Q[1][:] = 0.5
Q[2][:] = 0.75
Q
# Out:
# defaultdict(<function __main__.<lambda>()>,
#             {0: array([0.25, 0.25, 0.25, 0.25]),
#              1: array([0.5, 0.5, 0.5, 0.5]),
#              2: array([0.75, 0.75, 0.75, 0.75])})

# %%
for k, v in Q.items():
    for v_ in range(len(v)):
        print(k)
        print(v_)
# Out:
# 0
# 0
# 0
# 1
# 0
# 2
# 0
# 3
# 1
# 0
# 1
# 1
# 1
# 2
# 1
# 3
# 2
# 0
# 2
# 1
# 2
# 2
# 2
# 3
